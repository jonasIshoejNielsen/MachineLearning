# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("./inputs/lena.jpg")
#cvt = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cvt = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cvt)
